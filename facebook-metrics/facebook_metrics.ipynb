# %% [markdown]
# <font size="5">Imports</font>

# %%
import pandas as pd

# %% [markdown]
# <font size="5">Read Dataset</font>

# %%
df = pd.read_csv('dataset_Facebook.csv', delimiter=';')

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# <font size="5">Data Preprocessing</font>

# %%
df = df.dropna()
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# <font size="5">Creating Subsets</font>

# %%
post_types = df["Type"].unique()
post_types
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %%
photo_subset = df[df["Type"] == "Photo"]
status_subset = df[df["Type"] == "Status"]
link_subset = df[df["Type"] == "Link"]
video_subset = df[df["Type"] == "Video"]

# %%
photo_subset.head()
# Out:
#    Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441  Photo         2          12             4          3
# 2            139441  Photo         3          12             3          3
# 3            139441  Photo         2          12             2         10
# 4            139441  Photo         2          12             2          3
# 6            139441  Photo         3          12             1          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
# 6   1.0                      11692                            19479
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# ...

# %%
link_subset.head()
# Out:
#     Page total likes  Type  Category  Post Month  Post Weekday  Post Hour  \
# 22            138414  Link         1          12             7         10
# 41            138895  Link         1          12             6          3
# 43            138353  Link         1          12             5          3
# 45            138353  Link         1          12             4          3
# 47            138353  Link         1          12             3          2
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 22   0.0                       3454                             6853
# 41   1.0                      18480                            28438
# 43   1.0                       2645                             4270
# 45   1.0                       7968                            13023
# 47   0.0                       1925                             3481
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# <font size="5">Merging Subsets</font>

# %%
merged_photo_link = pd.concat([photo_subset, link_subset], keys=["photo_subset", "link_subset"])
merged_photo_link
# Out:
#                   Page total likes   Type  Category  Post Month  Post Weekday  \
# photo_subset 0              139441  Photo         2          12             4
#              2              139441  Photo         3          12             3
#              3              139441  Photo         2          12             2
#              4              139441  Photo         2          12             2
#              6              139441  Photo         3          12             1
# ...                            ...    ...       ...         ...           ...
# link_subset  470             91437   Link         1           2             3
#              477             86909   Link         1           1             6
#              481             86491   Link         1           1             4
#              485             86491   Link         1           1             2
#              492             85979   Link         1           1             5
#
# ...

# %% [markdown]
# <font size="5">Sort Data</font>

# %%
df.sort_values(by="Page total likes").head()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 498             81370  Photo         3           1             4         11
# 497             81370  Photo         1           1             5          2
# 496             81370  Photo         2           1             5          8
# 493             85093  Photo         3           1             1          2
# 495             85093  Photo         3           1             7          2
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 498   0.0                       4156                             7564
# 497   0.0                       3778                             7216
# 496   0.0                       3480                             6229
# 493   0.0                       8412                            13960
# 495   0.0                       4684                             7536
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# <font size="5">Transposing Data</font>

# %%
df_transposed = df.transpose()
df_transposed.head()
# Out:
#                      0       1       2       3       4       5       6    \
# Page total likes  139441  139441  139441  139441  139441  139441  139441
# Type               Photo  Status   Photo   Photo   Photo  Status   Photo
# Category               2       2       3       2       2       2       3
# Post Month            12      12      12      12      12      12      12
# Post Weekday           4       3       3       2       2       1       1
#
#                      7       8       9    ...    489    490    491    492  \
# Page total likes  139441  139441  139441  ...  85979  85979  85979  85979
# Type               Photo  Status   Photo  ...  Photo  Photo  Photo   Link
# Category               3       2       3  ...      3      3      3      1
# Post Month            12      12      12  ...      1      1      1      1
# Post Weekday           7       7       6  ...      7      6      6      5
#
#                     493    494    495    496    497    498
# ...

# %% [markdown]
# <font size="5">Melting Data</font>

# %%
df_melted = pd.melt(df)
df_melted.head()
# Out:
#            variable   value
# 0  Page total likes  139441
# 1  Page total likes  139441
# 2  Page total likes  139441
# 3  Page total likes  139441
# 4  Page total likes  139441

# %% [markdown]
# <font size="5">Casting Data</font>

# %%
df_casted = df.astype({'Paid': 'int32'})
df_casted.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0     0                       2752                             5091
# 1     0                      10460                            19057
# 2     0                       2413                             4373
# 3     1                      50128                            87991
# 4     0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...
